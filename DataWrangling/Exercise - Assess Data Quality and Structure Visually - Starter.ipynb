# %% [markdown]
# # Exercise - Assess Data Quality and Structure Visually
#
# In this exercise, we will be looking at synthetic phase two clinical trial dataset of 350 patients for a new innovative oral insulin called **Auralin** - a proprietary capsule that can solve a stomach lining problem.
#
# **Note:** Auralin and Novodra are not real insulin products. This clinical trial data was fabricated for the sake of this course. When assessing this data, the issues that you'll detect (and later clean) are meant to simulate real-world data quality and tidiness issues with the capability to **impact quality of care, patient registration, and revenue**. The datasets, `patients` and `treatments`, were constructed with the consultation of real doctors to ensure plausibility.

# %%
#DO NOT MODIFY - imports and loaing data
import pandas as pd

patients = pd.read_csv('patients.csv')
treatments = pd.read_csv('treatments.csv')

# %% [markdown]
# ## 1. Identify data quality issues in the patients data

# %% [markdown]
# The `patients` dataframe contains the following variables:
#
# - **patient_id**: the unique identifier for each patient
# - **assigned_sex**: the assigned sex of each patient at birth (male or female)
# - **given_name**: the given name (i.e. first name) of each patient
# - **surname**: the surname (i.e. last name) of each patient
# - **address**: the main address for each patient
# - **city**: the corresponding city for the main address of each patient
# - **state**: the corresponding state for the main address of each patient
# - **zip_code**: the corresponding zip code for the main address of each patient
# - **country**: the corresponding country for the main address of each patient (all United states for this clinical trial)
# - **contact**: phone number and email information for each patient
# - **birthdate**: the date of birth of each patient (month/day/year).
# > The [inclusion criteria](https://en.wikipedia.org/wiki/Inclusion_and_exclusion_criteria) for this clinical trial is  age >= 18 *(there is no maximum age because diabetes is a [growing problem](http://www.diabetes.co.uk/diabetes-and-the-elderly.html) among the elderly population)*
# - **weight**: the weight of each patient in pounds (lbs)
# - **height**: the height of each patient in inches (in)
# - **bmi**: the Body Mass Index (BMI) of each patient.
# > BMI is a simple calculation using a person's height and weight. The formula is BMI = kg/m<sup>2</sup> where kg is a person's weight in kilograms and m<sup>2</sup> is their height in metres squared. A BMI of 25.0 or more is overweight, while the healthy range is 18.5 to 24.9. *The [inclusion criteria](https://en.wikipedia.org/wiki/Inclusion_and_exclusion_criteria) for this clinical trial is 16 >= BMI >= 38.*

# %% [markdown]
# ### 1.1 Display dataset
#
# Display the first 10 rows of the patients data, and visually inspect the data, using directed and non-directed visual assessment as you see necessary.
#
# Identify **four** instances of problematic data points corresponding to **accuracy** and **validity** in the patients dataset.
#
# **Hint**: take a look at the `given_name`, `zip_code`, and `height` columns.

# %%
#FILL IN - inspect the first 10 rows of the patients data

patients.head(10)
# Out:
#    patient_id assigned_sex given_name     surname                     address  \
# 0           1       female        Zoe     Wellish        576 Brown Bear Drive
# 1           2       female     Pamela        Hill   2370 University Hill Road
# 2           3         male        Jae      Debord       1493 Poling Farm Road
# 3           4         male       Liêm        Phan         2335 Webster Street
# 4           5         male        Tim     Neudorf        1428 Turkey Pen Lane
# 5           6         male     Rafael       Costa          1140 Willis Avenue
# 6           7       female       Mary       Adams            3145 Sheila Lane
# 7           8       female     Xiuxiu       Chang  2687 Black Oak Hollow Road
# 8           9         male      Dsvid  Gustafsson          1790 Nutter Street
# 9          10       female     Sophie     Cabrera           3303 Anmoore Road
#
#                 city       state  zip_code        country  \
# 0  Rancho California  California   92390.0  United States
# 1          Armstrong    Illinois   61812.0  United States
# 2               York    Nebraska   68467.0  United States
# 3         Woodbridge          NJ    7095.0  United States
# 4             Dothan          AL   36303.0  United States
# 5      Daytona Beach     Florida   32114.0  United States
# 6            Burbank          NV   84728.0  United States
# 7        Morgan Hill          CA   95037.0  United States
# 8        Kansas City          MO   64105.0  United States
# 9           New York    New York   10011.0  United States
#
#                                          contact   birthdate  weight  height  \
# 0           951-719-9170ZoeWellish@superrito.com   7/10/1976   121.7      66
# 1          PamelaSHill@cuvox.de+1 (217) 569-3204    4/3/1967   118.8      66
# 2               402-363-6804JaeMDebord@gustr.com   2/19/1980   177.8      71
# 3     PhanBaLiem@jourrapide.com+1 (732) 636-8246   7/26/1951   220.9      70
# 4                334-515-7487TimNeudorf@cuvox.de   2/18/1928   192.3      27
# 5       386-334-5237RafaelCardosoCosta@gustr.com   8/31/1931   183.9      70
# 6              775-533-5933MaryBAdams@einrot.com  11/19/1969   146.3      65
# 7           XiuxiuChang@einrot.com1 408 778 3236   8/13/1958   158.0      60
# 8        816-265-9578DavidGustafsson@armyspy.com    3/6/1937   163.9      66
# 9  SophieCabreraIbarra@teleworm.us1 718 795 9124   12/3/1930   194.7      64
#
#     bmi
# 0  19.6
# 1  19.2
# 2  24.8
# 3  31.7
# 4  26.1
# 5  26.4
# 6  24.3
# 7  30.9
# 8  26.5
# 9  33.4

# %%
#FILL IN - More code if needed
patients.nunique()
# Out:
# patient_id      503
# assigned_sex      2
# given_name      470
# surname         466
# address         483
# city            349
# state            54
# zip_code        430
# country           1
# contact         483
# birthdate       493
# weight          347
# height           22
# bmi             183
# dtype: int64

# %%
# Select specific columns and display the first 10 rows
patients[['given_name', 'zip_code', 'height']].head(10)
#patients['given_name'].unique()
patients['zip_code'].unique()
#patients['height'].unique()
# Filter rows where 'zip_code' is None and display the first 10
patients[patients['zip_code'].isna()].head(10)
# Out:
#      patient_id assigned_sex given_name      surname address city state  \
# 209         210       female     Lalita  Eldarkhanov     NaN  NaN   NaN
# 219         220         male         Mỹ        Quynh     NaN  NaN   NaN
# 230         231       female  Elisabeth      Knudsen     NaN  NaN   NaN
# 234         235       female    Martina    Tománková     NaN  NaN   NaN
# 242         243         male       John      O'Brian     NaN  NaN   NaN
# 249         250         male   Benjamin       Mehler     NaN  NaN   NaN
# 257         258         male        Jin         Kung     NaN  NaN   NaN
# 264         265       female   Wafiyyah       Asfour     NaN  NaN   NaN
# 269         270       female     Flavia   Fiorentino     NaN  NaN   NaN
# 278         279       female   Generosa        Cabán     NaN  NaN   NaN
#
#      zip_code country contact   birthdate  weight  height   bmi
# 209       NaN     NaN     NaN   8/14/1950   143.4      62  26.2
# 219       NaN     NaN     NaN    4/9/1978   237.8      69  35.1
# 230       NaN     NaN     NaN   9/23/1976   165.9      63  29.4
# 234       NaN     NaN     NaN    4/7/1936   199.5      65  33.2
# 242       NaN     NaN     NaN   2/25/1957   205.3      74  26.4
# 249       NaN     NaN     NaN  10/30/1951   146.5      69  21.6
# 257       NaN     NaN     NaN   5/17/1995   231.7      69  34.2
# 264       NaN     NaN     NaN   11/3/1989   158.6      63  28.1
# 269       NaN     NaN     NaN   10/9/1937   175.2      61  33.1
# 278       NaN     NaN     NaN  12/16/1962   124.3      69  18.4

# %%
# Unique 
patients[patients['surname']=='Doe']

patients['contact'].unique()
# Out:
# array(['951-719-9170ZoeWellish@superrito.com',
#        'PamelaSHill@cuvox.de+1 (217) 569-3204',
#        '402-363-6804JaeMDebord@gustr.com',
#        'PhanBaLiem@jourrapide.com+1 (732) 636-8246',
#        '334-515-7487TimNeudorf@cuvox.de',
#        '386-334-5237RafaelCardosoCosta@gustr.com',
#        '775-533-5933MaryBAdams@einrot.com',
#        'XiuxiuChang@einrot.com1 408 778 3236',
#        '816-265-9578DavidGustafsson@armyspy.com',
#        'SophieCabreraIbarra@teleworm.us1 718 795 9124',
#        '906-478-8949SandyGunnarsson@dayrep.com',
#        'Abdul-NurMummarIsa@rhyta.com1 931 207 0839',
#        'OmeokachieIbeamaka@einrot.com434-509-2614',
#        'AnenechiChidi@armyspy.com+1 (205) 417-8095',
#        'AsiaWozniak@rhyta.com918-712-3469',
#        '276-225-1955SrenFLund@gustr.com',
#        'LieuThiThuTam@dayrep.com1 559 765 7836',
#        'RoxanneAndreyeva@armyspy.com678-829-8578',
#        '406-775-2696WilliamVOates@armyspy.com',
#        'ZakKelly@rhyta.com1 530 532 8397',
#        'SofiaTKarlsen@teleworm.us1 781 447 1763',
#        '973-445-5341SamuelGubrandsson@teleworm.us',
#        '914-745-6108ManchuSu@einrot.com',
#        'LovreGalic@gustr.com1 813 355 9476',
#        'JakobCJakobsen@einrot.com+1 (845) 858-7707',
#        'GregorBole@gustr.com505-828-4955',
#        '309-671-8852EllaLund@armyspy.com',
#        '985-814-7603JosephNTucker@rhyta.com',
#        'RobertWolf@fleckens.hu1 267 895 7462',
#        '303-910-2058JaninaBazarova@superrito.com',
#        '423-538-4887TomasNavratil@dayrep.com',
#        'PhamThiBichMot@dayrep.com562-985-4582',
#        '815-270-7770HabteKifle@fleckens.hu',
#        '207-825-8634MarianaGomesSouza@superrito.com',
#        '718-501-0503KamilaPecinova@dayrep.com',
#        'NajaEnoksen@fleckens.hu715-562-7013',
#        'AlbincaKomavec@rhyta.com+1 (605) 204-6572',
#        'GenetFesahaye@armyspy.com1 978 460 9060',
#        '508-454-2027GanimeteScancar@cuvox.de',
#        'TjesimirLukic@jourrapide.com1 404 547 4508',
#        'FakhriHaniFakhoury@cuvox.de320-826-3340',
#        'MizukiIwata@gustr.com561-357-0702',
#        'SchmittZizi@fleckens.hu1 307 712 0508',
#        'BlankaJurkovic@superrito.com1 207 861 4587',
#        'LiisaSeppala@einrot.com1 731 632 2908',
#        '724-419-3583JavierMoquin@rhyta.com',
#        '404-289-1766AnaSousaCorreia@rhyta.com',
#        'AnnikaVaara@rhyta.com312-719-7238',
#        '419-262-6953ZsinkoVivien@teleworm.us',
#        'StephenGibson@cuvox.de570-819-1140',
#        'NoeArandaGranado@dayrep.com1 309 912 9553',
#        '515-727-9324BriannaLansell@fleckens.hu',
#        '617-317-5055KwemtochukwuOgochukwu@einrot.com',
#        'LouiseJohnson@rhyta.com978-407-1874',
#        'AncoPak@cuvox.de1 702 730 5584',
#        'AlissaMontezFranco@gustr.com+1 (706) 497-0891',
#        'SiebrigjeKoldenhof@rhyta.com858-413-3163',
#        'YasminCardosoAraujo@superrito.com412-640-7035',
#        'AvdeiTikhonov@gustr.com1 252 291 3898',
#        '619-570-3898BarboraVesecka@gustr.com',
#        'AlanMilne@dayrep.com1 661 779 6795',
#        '617-883-5967FodorFirenze@dayrep.com',
#        '619-299-1495YukitakaTakenaka@einrot.com',
#        'JaakkoEskelinen@superrito.com+1 (315) 362-5858',
#        'NicolasSouzaFerreira@superrito.com765-379-3885',
#        '760-287-8295KonstantynKowalczyk@armyspy.com',
#        'NebechiEkechukwu@teleworm.us508-804-4850',
#        '414-646-4353HarunaAzuma@gustr.com',
#        'JosephMDay@teleworm.us+1 (773) 615-9328',
#        'AlexanderEMathiesen@superrito.com1 740 629 5172',
#        '860-515-0122LeucoMirandaNieto@teleworm.us',
#        'SrenFrederiksen@armyspy.com504-289-1386',
#        '978-969-6753ZarkaRap@superrito.com',
#        '918-975-7594HankaGegic@fleckens.hu',
#        'LeoMancini@rhyta.com+1 (510) 498-6624',
#        '612-925-3123MaryamDratchev@superrito.com',
#        '859-297-3368RutHalldorsdottir@einrot.com',
#        'FaunaBilodeau@teleworm.us1 774 263 5317',
#        '302-397-6035EnizKonovsek@superrito.com',
#        'EufemioRosarioAlarcon@gustr.com+1 (646) 621-0640',
#        '580-934-1141AndreNordin@cuvox.de',
#        '678-350-2390ThachThiKieuChau@superrito.com',
#        '937-523-1224ChenYao@teleworm.us',
#        'VuCamNuong@fleckens.hu516-720-5094',
#        '407-662-9389BurrellMathieu@teleworm.us',
#        '240-695-5212PhilemonAbdulov@rhyta.com',
#        'MagomedKadyrov@jourrapide.com320-272-4299',
#        '706-755-5723MariusHansen@teleworm.us',
#        'KwasiMensa@cuvox.de+1 (480) 967-6336',
#        'IngoRokavc@superrito.com+1 (585) 902-9127',
#        'CarolineTShuler@jourrapide.com713-230-1739',
#        '609-914-8473MichaelSmith@armyspy.com',
#        '786-234-0038ElliotRichardson@teleworm.us',
#        '305-361-8416GinaACain@armyspy.com',
#        '325-282-4087SargentRuais@jourrapide.com',
#        '207-768-0477NasimSumaiyaSalib@einrot.com',
#        'PatrickGersten@rhyta.com402-848-4923',
#        'JanBaum@superrito.com+1 (907) 328-4125',
#        'BerndSchneider@jourrapide.com914-830-3940',
#        '701-676-6301IsacBerg@cuvox.de',
#        'OlesZhdanov@fleckens.hu417-738-5084',
#        'NajlaQismahTouma@cuvox.de+1 (334) 261-1235',
#        'TicoKoffeman@armyspy.com+1 (407) 838-0201',
#        'YasminAlmeidaSilva@einrot.com1 602 265 7408',
#        'NateBowden@einrot.com919-915-8670',
#        'InunnguaqHeilmann@rhyta.com1 765 599 8847',
#        '240-322-1398RoccoChristie@rhyta.com',
#        'MarinaGlockner@dayrep.com1 620 940 1131',
#        '601-699-4153StephenFMayberry@jourrapide.com',
#        'MiroslavStepanek@teleworm.us+1 (214) 637-0855',
#        '661-291-1812NicoleZimmerman@rhyta.com',
#        'ArnruurSkarpheinsdottir@rhyta.com+1 (757) 885-5669',
#        'SvanhvitGujonsdottir@cuvox.de1 713 779 6516',
#        '917-256-5329YunadiBarsukov@teleworm.us',
#        'CarolineBois@rhyta.com1 707 262 6503',
#        '606-417-4332PhilippZiegler@superrito.com',
#        'TaQuiSuu@teleworm.us+1 (504) 528-8317',
#        '337-685-4885AdibMutazzGhanem@fleckens.hu',
#        '832-457-6625ChajaBouw@dayrep.com',
#        '415-676-8818NicolinePstergaard@superrito.com',
#        'FrydrykAdamski@armyspy.com1 315 869 4408',
#        'TaHaBoi@superrito.com231-607-3625',
#        '727-331-8429FejesTas@jourrapide.com',
#        'MingHsu@armyspy.com+1 (508) 526-3432',
#        '918-714-7543SewerynaCzerwinska@jourrapide.com',
#        'MadsANielsen@jourrapide.com508-739-5632',
#        '360-482-2553LenaBaer@rhyta.com',
#        'MuhammadHughes@rhyta.com1 317 292 2394',
#        '631-370-7406RebeccaJephcott@armyspy.com',
#        '843-494-0313AlbertRWolfe@jourrapide.com',
#        '304-438-2648SandraCTaylor@dayrep.com',
#        'TeklaWalczak@einrot.com570-698-4203',
#        'ElisabethDimmen@cuvox.de+1 (803) 465-3312',
#        'JesseLuoma@fleckens.hu+1 (518) 212-7081',
#        'Willem-JanvanderLubbe@gustr.com440-385-5011',
#        '714-507-4204VictoriaTMikkelsen@armyspy.com',
#        '954-784-6658EmmaBarlow@superrito.com',
#        '804-908-1436JoseRCombs@rhyta.com',
#        'NovalieBerg@gustr.com+1 (513) 383-0516',
#        '217-421-0935JohnTeichelmann@dayrep.com',
#        '903-644-2098EvelynUspenskaya@rhyta.com',
#        '516-740-5280FinleyChandler@dayrep.com',
#        '206-902-0473AmandaCavalcantiRibeiro@fleckens.hu',
#        '260-591-5755MileStanic@dayrep.com',
#        'SauliKoivuniemi@einrot.com+1 (267) 679-4137',
#        'HaylomNebay@gustr.com1 219 391 7729',
#        '310-268-6864KristianVukelic@teleworm.us',
#        '718-418-0766RietteScheltens@dayrep.com',
#        '830-640-5848WawrzyniecNowakowski@teleworm.us',
#        '863-438-6922FelicijanBubanj@einrot.com',
#        '916-224-7868SatsitaBatukayev@teleworm.us',
#        'ChristopherWoodward@jourrapide.com+1 (516) 630-5900',
#        'JohnACarreiro@superrito.com1 775 770 7827',
#        'MayaIsaksson@jourrapide.com1 608 277 0146',
#        '618-261-9896NinaGeisler@einrot.com',
#        'LeVietThong@gustr.com+1 (612) 208-2965',
#        'EllenRLuman@einrot.com920-849-0384',
#        'ChibuzoOkoli@einrot.com+1 (918) 971-5864',
#        'CoralieAllaire@armyspy.com+1 (828) 586-5050',
#        'FlavianoEndrizzi@cuvox.de602-993-7880',
#        '406-759-6160MitsunobuFujiwara@armyspy.com',
#        'SarinaTabata@teleworm.us916-555-7247',
#        '803-712-1180HawraSultanahTuma@superrito.com',
#        '913-393-8663LamHoangHuong@rhyta.com',
#        'ZlatkoRukavina@cuvox.de+1 (662) 716-9586',
#        '903-749-8046PeterPospisil@cuvox.de',
#        '781-604-1901MelisaMataSantacruz@rhyta.com',
#        '650-849-6900GalitCasarezBrito@jourrapide.com',
#        '302-474-8075MarkusSolberg@fleckens.hu',
#        '718-628-9500ChikereAchebe@jourrapide.com',
#        '815-533-7692BlagicaKlobucar@einrot.com',
#        '319-541-3295AlvinAJackson@armyspy.com',
#        'MarijaGrubisic@cuvox.de248-944-0932',
#        '509-466-2907MichelleDTansey@dayrep.com',
#        'KatrineLynge@gustr.com1 217 491 5261',
#        'MakdaAbraham@einrot.com1 508 857 0477',
#        '323-327-4721MonikaLoncar@rhyta.com',
#        '773-934-7423ElseAndersen@rhyta.com',
#        '641-753-5678DominikGrunewald@cuvox.de',
#        '318-417-5739TrianaTerrazasMoreno@superrito.com',
#        'YumenaNakayama@gustr.com1 970 754 5843',
#        '201-739-3931KaodilinakachukwuNnonso@gustr.com',
#        '909-355-9418SuhaimAbdelRahal@fleckens.hu',
#        'AstaGrimsdottir@dayrep.com+1 (386) 989-0019',
#        'BriceAuthier@superrito.com1 989 375 2216',
#        'JaneCitizen@cuvox.de+1 (401) 485-6384',
#        '773-607-2647WladyslawWieczorek@teleworm.us',
#        'SrenSrensen@superrito.com1 212 201 3108',
#        'KisanetSelassie@gustr.com+1 (916) 453-3601',
#        'RegoloNucci@einrot.com+1 (724) 449-6928',
#        'FanetteFournier@einrot.com+1 (312) 864-5737',
#        '631-704-6487JadeParker@superrito.com',
#        'BornaSlezinger@cuvox.de203-933-3979',
#        '609-466-3275UrsoArandaSanchez@rhyta.com',
#        '985-253-7891LamaraDratchev@teleworm.us',
#        '512-738-2609AlbinaZetticci@teleworm.us',
#        'LuongKhacThe@dayrep.com1 989 705 7690',
#        'EufrosinaSchiavone@cuvox.de+1 (859) 977-9462',
#        'ZdenekSynek@jourrapide.com1 205 648 4197',
#        '856-655-5415KifleMustafa@gustr.com',
#        'PirroGalvezPaz@armyspy.com1 603 773 2333',
#        'JirinaSubrtova@rhyta.com503-820-7877',
#        '636-442-6946LuongHongMui@einrot.com',
#        'LeixandreAlanisMadrigal@fleckens.hu405-234-5350',
#        '716-743-5884BrenoLimaCorreia@superrito.com',
#        '806-323-2210LeahWong@einrot.com',
#        '989-936-4563BeatryczeWozniak@armyspy.com',
#        'GabrieleSaenger@armyspy.com+1 (817) 909-5667', nan,
#        '330-202-2145CamillaZaitseva@superrito.com',
#        'MarthaAfanasyeva@dayrep.com1 612 228 4170',
#        'JensPoulsen@fleckens.hu704-805-5094',
#        '917-622-9142OnyemaechiOnwughara@einrot.com',
#        'GabrielaMichalcikova@rhyta.com+1 (802) 952-6490',
#        'johndoe@email.com1234567890',
#        '646-472-4758GabrielleBidwill@teleworm.us',
#        'SaidmohmadRushisvili@teleworm.us706-266-4583',
#        '423-563-2014SabrRumaithahAmari@fleckens.hu',
#        'MijaelGuerraMoreno@teleworm.us+1 (707) 896-9250',
#        'SagiCsaba@armyspy.com+1 (267) 932-9852',
#        '502-367-6167MalinaBalagic@einrot.com',
#        'VirginiaABoyles@gustr.com1 208 897 3897',
#        '802-614-0812VeronikaJindrova@jourrapide.com',
#        'RachelSGuzman@cuvox.de202-485-6607',
#        'KariHervinsson@einrot.com914-784-6646',
#        '402-938-2157LauraEhrlichmann@einrot.com',
#        'CsorbaCintia@fleckens.hu916-379-7480',
#        'StefanieHerman@fleckens.hu1 252 583 5410',
#        'KyoukoOno@superrito.com1 858 587 9945',
#        'AngelaLavrentyev@gustr.com504-546-5321',
#        '606-368-9825JustynaKowalczyk@jourrapide.com',
#        '303-360-3627FatimahKinfe@fleckens.hu',
#        'AkselHVestergaard@armyspy.com215-528-2193',
#        '228-378-1355KhalidJohnsrud@teleworm.us',
#        'MarphisaCompagnon@cuvox.de+1 (256) 615-5522',
#        '901-484-5225SkyeGormanston@dayrep.com',
#        '715-817-0134MustafaAdonay@dayrep.com',
#        '815-979-8782IsabelleNash@einrot.com',
#        '714-431-2746MeyaSjoberg@cuvox.de',
#        '917-408-8855TuukkaLeppaluoto@teleworm.us',
#        'CecilieNilsen@superrito.com308-496-7837',
#        '410-284-8935MeeChung@teleworm.us',
#        '978-243-8596JuanPerez@teleworm.us',
#        '321-287-0484MagyarKrisztina@superrito.com',
#        '412-274-6756KangMai@jourrapide.com',
#        'MetteSandgreen@gustr.com715-231-3508',
#        'VeronicaBogolyubova@teleworm.us570-797-6666',
#        'AbelYonatan@teleworm.us1 818 841 7660',
#        '727-439-7150SaraDMiles@gustr.com',
#        'EmilyNHenriksen@armyspy.com925-757-6139',
#        'JeremyMontagu@teleworm.us617-297-0387',
#        '713-556-4328RebeccaRPriest@dayrep.com',
#        'JuliaAzevedoCarvalho@superrito.com+1 (212) 782-4151',
#        'orunnTryggvadottir@dayrep.com+1 (989) 826-7884',
#        'JohannaDreher@superrito.com1 606 632 4327',
#        'BernardaCindric@teleworm.us+1 (785) 823-6728',
#        '650-631-0002PaiviMattila@rhyta.com',
#        'JowitaWisniewska@armyspy.com+1 (618) 512-3319',
#        'RussomAmanuel@armyspy.com956-380-7249',
#        'KlementynaSokolowska@superrito.com+1 (937) 518-7238',
#        '601-848-3093MackenzieMcKay@superrito.com',
#        '740-552-2444NoraNyborg@einrot.com',
#        'EddieAArcher@gustr.com+1 (224) 305-6805',
#        'AlexCrawford@dayrep.com+1 (208) 264-9063',
#        '304-567-9723Hanna-MariFilatov@fleckens.hu',
#        '210-218-3477DavidLBeauvais@rhyta.com',
#        '205-494-6040KristjanIngason@gustr.com',
#        'NwachukwuNebeolisa@cuvox.de+1 (708) 845-2053',
#        '774-219-3140NiltonQuintanillaAlmonte@rhyta.com',
#        'AydenAllan@rhyta.com580-991-9678',
#        'KariLaatikainen@fleckens.hu1 619 818 3436',
#        '831-427-4114FareeqJawharKalb@armyspy.com',
#        'UrsulaFreud@cuvox.de504-441-7744',
#        '781-739-0244UnaTraustadottir@armyspy.com',
#        '302-698-2057EncoZibrik@superrito.com',
#        'FraserHunter@teleworm.us815-457-5970',
#        'JeramyAHopkins@teleworm.us408-834-4087',
#        'AnnieJAllen@superrito.com1 508 921 6327',
#        'AlbinoSchiavone@fleckens.hu1 916 817 9960',
#        '724-759-0310CsonkaBodor@jourrapide.com',
#        '361-533-5161ConnorHarold@fleckens.hu',
#        '208-826-1678LindaJLundy@gustr.com',
#        '706-616-0152BenignaFerrari@einrot.com',
#        'OnyekachukwuObinna@teleworm.us646-982-6609',
#        'NielsLange@cuvox.de601-296-7799',
#        'JoeVEdwards@armyspy.com1 313 589 1746',
#        '502-902-6188SignyGrimsdottir@rhyta.com',
#        'AddolorataLombardi@jourrapide.com+1 (607) 348-5625',
#        '402-780-5724MijndertOuwendijk@jourrapide.com',
#        '228-237-2271MatheaLilleb@fleckens.hu',
#        '631-875-3023DaudBatukayev@teleworm.us',
#        '256-872-9211ValurBjarkason@cuvox.de',
#        'HugoCollins@cuvox.de1 913 322 9114',
#        'EricaMacDonald@teleworm.us601-389-7682',
#        'HollyMacleod@jourrapide.com1 323 280 6511',
#        '251-359-2088MgbankwoAfamefuna@einrot.com',
#        '908-884-4247RenzoLucchese@dayrep.com',
#        'BrancaleoneRusso@jourrapide.com+1 (830) 851-4280',
#        '413-259-3637BuiQuynhChan@fleckens.hu',
#        'NancyJParker@gustr.com+1 (702) 438-5138',
#        'BenoitBonami@gustr.com1 718 954 8136',
#        '701-235-3404WilmaOlofsson@teleworm.us',
#        '262-565-9052NoriyukiSakai@gustr.com',
#        'DalmaciaMadridValenzuela@einrot.com1 504 403 4615',
#        '254-546-2728LieuThanhMuoi@teleworm.us',
#        'PolakNancsi@cuvox.de1 513 478 6938',
#        '202-238-2247KongLei@fleckens.hu',
#        'SaraKarjalainen@armyspy.com1 312 856 6826',
#        '518-379-0603SuomaKoivunen@gustr.com',
#        '908-871-7009TorfiIrisarson@jourrapide.com',
#        'AnjaHueber@teleworm.us+1 (612) 342-6065',
#        'HerczeghCsilla@jourrapide.com1 813 434 8122',
#        'VascovandeWiel@rhyta.com+1 (843) 368-5129',
#        'LeonScholz@fleckens.hu1 323 635 9919',
#        'AbelEfrem@fleckens.hu1 615 755 8235',
#        'JadAllahSayyarGaber@rhyta.com1 260 623 1176',
#        '630-837-9473EugeneMironov@dayrep.com',
#        '765-359-0147LixueHsueh@dayrep.com',
#        '248-978-1574SharonLCollins@jourrapide.com',
#        '208-830-2415LeonReynosoRendon@einrot.com',
#        'LoaHrafnsdottir@jourrapide.com+1 (985) 335-8662',
#        'PavelFilipek@rhyta.com1 952 431 5166',
#        '661-265-8708MineaLindgren@jourrapide.com',
#        'FatimahAqilahKhoury@superrito.com1 949 290 0728',
#        'MathildeDNrgaard@superrito.com1 860 618 4560',
#        '203-251-3573EmyMarkus@armyspy.com',
#        '404-713-3641SophiaHaugen@dayrep.com',
#        '219-843-3924AsunaMorita@superrito.com',
#        'HelenLuwam@dayrep.com607-206-1483',
#        '858-273-2043UrskaAlicajic@rhyta.com',
#        'SaberMenard@rhyta.com+1 (608) 527-1021',
#        'KristofferMartinsen@dayrep.com360-494-5489',
#        'BuiKimDiet@rhyta.com+1 (972) 557-0198',
#        '423-799-1730NileMehari@gustr.com',
#        '912-988-6655MarekDvorak@gustr.com',
#        'OlePetersen@armyspy.com478-676-7058',
#        '201-586-2848VivianRHouse@dayrep.com',
#        'ChihoHiga@teleworm.us401-456-2797',
#        'SineadReilly@cuvox.de+1 (225) 695-5230',
#        '937-592-9410ChiemelaTobeolisa@rhyta.com',
#        'AmalieJChristensen@einrot.com1 203 235 1076',
#        '254-518-6365MerciLeroux@jourrapide.com',
#        'KermanDandonneau@superrito.com1 678 412 3728',
#        'HansPeterRadislav@gustr.com915-612-1462',
#        '757-624-1525LubosPecha@rhyta.com',
#        '562-452-5685ElisabettaLorenzo@gustr.com',
#        '818-372-7106ChukwumogeOgochukwu@teleworm.us',
#        'RobertWagner@jourrapide.com540-986-1369',
#        'ErickSouzaPinto@cuvox.de605-250-4942',
#        '775-358-9076AvaFisher@rhyta.com',
#        'CoreyNicholls@jourrapide.com1 617 830 7216',
#        '619-652-0285FarizahAminehSleiman@teleworm.us',
#        '508-821-2421OlofHolm@gustr.com',
#        'AsyaMusliyevich@armyspy.com+1 (908) 287-7099',
#        'MiloslawWisniewski@rhyta.com618-346-3914',
#        'JohanaHrda@dayrep.com479-248-5663',
#        '509-397-8510Ingirainsson@dayrep.com',
#        'SofiaBHermansen@rhyta.com985-580-4827',
#        'IvonaJaksic@einrot.com+1 (501) 636-4058',
#        '217-485-5673CumelenMiramontesAcosta@gustr.com',
#        'FurutaOsman@rhyta.com1 901 316 3780',
#        '580-622-5674RovzanKishiev@armyspy.com',
#        'SiljeAKristiansen@dayrep.com609-641-2070',
#        'RonnieKClapp@gustr.com+1 (870) 457-5086',
#        '989-822-1351DirikMariasson@jourrapide.com',
#        'TorbenMMortensen@einrot.com1 208 657 2473',
#        'EvenKnutsen@rhyta.com+1 (605) 440-5492',
#        'RiceYudina@dayrep.com434-361-8479',
#        '408-215-6012SargentFlamand@dayrep.com',
#        '561-826-5683VallieSPrince@cuvox.de',
#        '318-621-7385TotthSzilveszter@jourrapide.com',
#        '918-459-9811YegorUspensky@fleckens.hu',
#        '979-639-7844HidekiHaraguchi@einrot.com',
#        '786-970-4206DaimyTromp@superrito.com',
#        '630-252-5095KristinBorgen@gustr.com',
#        'StevenBRoy@rhyta.com1 703 716 8652',
#        '903-939-1025AnjaMueller@gustr.com',
#        '336-677-8769BakosKrisztian@teleworm.us',
#        '863-386-3795GyenesTibor@jourrapide.com',
#        '585-889-5156PipalukPetrussen@rhyta.com',
#        'IlijaHorvat@dayrep.com+1 (706) 777-4981',
#        'EricEk@jourrapide.com+1 (360) 965-1558',
#        '920-892-2965SonyaWoldendorp@cuvox.de',
#        'KasumiHori@gustr.com+1 (785) 748-8181',
#        '601-885-6550ManouckWubbels@armyspy.com',
#        'RobertMaslov@fleckens.hu401-535-2675',
#        'AaliyahRice@dayrep.com409-944-6516',
#        '541-967-9779MarcelPeters@rhyta.com',
#        'NemetDaniel@cuvox.de+1 (706) 581-5226',
#        '405-470-5088TeganJohnson@gustr.com',
#        'GiovanaAzevedoRocha@superrito.com+1 (989) 390-0285',
#        'AlbikaIbragimov@superrito.com716-897-5050',
#        'NathanCumpston@rhyta.com1 405 449 7960',
#        'StefanijaNovosel@teleworm.us1 518 487 4865',
#        'FinlaySheppard@fleckens.hu+1 (513) 297-6359',
#        '313-341-7799KaiOliveiraCunha@cuvox.de',
#        '937-526-1152BartoszWysocki@cuvox.de',
#        '909-861-4356MgbekeEkwueme@cuvox.de',
#        '631-664-4813DaniMuhsinAntoun@armyspy.com',
#        '360-689-4989XiuxiuYuan@superrito.com',
#        'MahmudKadyrov@gustr.com1 701 745 2700',
#        '317-956-6166MaretSultygov@teleworm.us',
#        '631-479-8171AdlanShishani@gustr.com',
#        '870-270-5502ArminaSauve@dayrep.com',
#        '641-475-9654GyorfyJazmin@jourrapide.com',
#        'SimoneBaumgaertner@teleworm.us719-661-6624',
#        'KrystianaKozlowska@cuvox.de+1 (401) 419-2975',
#        '908-751-4255TaylahMobourne@rhyta.com',
#        '305-434-6299RogelioJTaylor@teleworm.us',
#        '325-513-8964TeclaOnio@jourrapide.com',
#        '412-319-0903MarkoKos@einrot.com',
#        'KristiinaHyypia@cuvox.de218-773-9682',
#        'TimothyJCotton@dayrep.com701-662-1983',
#        '510-376-3772ManuelaCindric@gustr.com',
#        'KarenJakobsen@jourrapide.com1 979 203 0438',
#        '412-449-0733LeoDVieira@cuvox.de',
#        'BaoShe@rhyta.com+1 (323) 209-0527',
#        'IvanaKasna@teleworm.us+1 (757) 736-7026',
#        '703-547-0551SunKo@einrot.com',
#        'AlwinSvensson@armyspy.com+1 (262) 878-9576',
#        '330-365-4059HannahMcIntosh@superrito.com',
#        'HiromuHorikawa@superrito.com1 515 362 6574',
#        'DavidMVilladsen@armyspy.com+1 (573) 493-4748',
#        '559-693-6779LuisRibeiroSilva@jourrapide.com',
#        '516-512-4875AnaniasEnriquezMontoya@armyspy.com',
#        'KajsaEidem@superrito.com352-362-5392',
#        '415-277-2563AngelicoMarchesi@fleckens.hu',
#        'MaximusHenzen@einrot.com408-792-9489',
#        '601-418-0102EemilLaine@einrot.com',
#        '708-691-2195LuizCavalcantiGomes@rhyta.com',
#        '216-502-3773IvanFomin@dayrep.com',
#        'BjrnarNilsen@einrot.com+1 (215) 769-7116',
#        '516-626-8021ClintonKMiller@rhyta.com',
#        'JiaLiTeng@fleckens.hu1 909 982 4264',
#        '717-368-8321FearneMcGregor@superrito.com',
#        '281-556-4376WuSung@gustr.com',
#        'BiancaCarvalhoAzevedo@einrot.com1 606 589 2819',
#        '215-321-9611HuiCheng@rhyta.com',
#        'ZikoranaudodimmaChinedum@cuvox.de1 757 269 6500',
#        '817-777-5289MevlaGrabljevec@teleworm.us',
#        'SousukeNakahara@jourrapide.com775-848-6970',
#        '619-710-6286IdaliaEMoore@cuvox.de',
#        'ArneJrgensen@fleckens.hu+1 (510) 238-1151',
#        '646-289-4177CannanCabreraOrdonez@superrito.com',
#        '213-749-6958GuniHeimisson@superrito.com',
#        'BoukeGlaser@einrot.com1 573 437 7334',
#        'MeazaBrhane@superrito.com205-467-9279',
#        'GabrysTomaszewski@armyspy.com254-582-1795',
#        'AndreaBrodahl@armyspy.com+1 (612) 589-1495',
#        '530-773-9263JozkaResanovic@superrito.com',
#        '573-728-3861ToshCJensen@superrito.com',
#        '910-264-6229HarleyTucker@fleckens.hu',
#        '386-234-5932MuhammadHolden@fleckens.hu',
#        '503-417-1995NadwahHawadahNaifeh@einrot.com',
#        '601-446-6829JuliaWerner@teleworm.us',
#        'KateWilkinson@armyspy.com1 508 905 2371',
#        'EsperanzaLabrosse@armyspy.com678-263-3564',
#        'MalikVaneker@superrito.com650-962-7179',
#        '267-972-3749BertaNapolitani@rhyta.com',
#        'JuliuszMajewski@superrito.com+1 (843) 212-6421',
#        'EdelmaVillalpandoSantillan@teleworm.us+1 (415) 755-6435',
#        'TapaArsanukayev@dayrep.com1 909 458 2515',
#        'NasserMazinMansour@fleckens.hu1 210 326 5509',
#        'MichaelKristensen@gustr.com1 918 706 2776',
#        '361-693-4960DiogoBarrosSouza@jourrapide.com',
#        '731-577-0292AngelGrant@fleckens.hu',
#        '336-697-2005PlacidoUdinesi@dayrep.com',
#        'TrifonIzmailov@fleckens.hu1 850 659 0417',
#        '254-681-4504SamuelBlix@dayrep.com',
#        'IvarLofgren@armyspy.com1 785 229 1188',
#        '352-453-4601MikaMartinsson@armyspy.com',
#        'JasmineSykes@jourrapide.com925-283-5425',
#        '914-636-9304JacksonAddison@armyspy.com',
#        '210-222-8684VanessaFerguson@jourrapide.com',
#        '714-496-2264TarPoldi@superrito.com',
#        'FenChin@gustr.com+1 (208) 388-1065',
#        'SirkkaPiirainen@teleworm.us+1 (586) 790-0975',
#        '650-570-4896HajimeTsukada@dayrep.com',
#        'AlexanderHueber@jourrapide.com1 209 762 2320',
#        'MasatakaMurakami@einrot.com+1 (918) 984-9171',
#        '207-477-0579MustafaLindstrom@jourrapide.com',
#        '928-284-4492RumanBisliev@gustr.com',
#        '816-223-6007JinkedeKeizer@teleworm.us',
#        'ChidaluOnyekaozulu@jourrapide.com1 360 443 2060'], dtype=object)

# %% [markdown]
# ### 1.2 Identify issues
#
# FILL IN the identified issues. For each issue, denote the row and column where the issue takes place:
#
# - Issue 1 (Accuracy): Row ..., column ...  Address is missing in a number of columns
# - Issue 2 (Accuracy): Row ... email and phone numbers are stored in one variable
# - Issue 3 (Validity): Row ..., 215 ...  There are duplicates for John Doe in terms of address and patients id.
# - Issue 4 (Validity): Row ..., email is inconsistant with phone numbers stored in the begining or the end of the string

# %% [markdown]
# ## 2. Identify data quality and structural issues in the treatments data
#
# Let's take a look at brief context around the `treatments` data:
#
# 350 patients participated in this clinical trial. None of the patients were using **Novodra** (a popular injectable insulin) or **Auralin** (the oral insulin being researched) as their primary source of insulin before.  All were experiencing elevated HbA1c levels.
# > HbA1c stands for Hemoglobin A1c. The [HbA1c test](https://depts.washington.edu/uwcoe/healthtopics/diabetes.html) measures what the average blood sugar has been over the past three months. It is thus a powerful way to get an overall sense of how well diabetes has been controlled. Everyone with diabetes should have this test 2 to 4 times per year. Measured in %.
#
# All 350 patients were treated with Novodra to establish a baseline HbA1c level and insulin dose. After four weeks:
# - 175 patients switched to Auralin for 24 weeks
# - 175 patients continued using Novodra for 24 weeks
#
# `treatments` columns:
# - **given_name**: the given name of each patient in the Master Patient Index that took part in the clinical trial
# - **surname**: the surname of each patient in the Master Patient Index that took part in the clinical trial
# - **auralin**: the baseline median daily dose of insulin from the week prior to switching to Auralin (the number before the dash `-`) *and* the ending median daily dose of insulin at the end of the 24 weeks of treatment measured over the 24th week of treatment (the number after the dash `-`). Both are measured in units (shortform 'u'), which is the [international unit](https://en.wikipedia.org/wiki/International_unit) of measurement and the standard measurement for insulin.
# - **novodra**: same as above, except for patients that continued treatment with Novodra
# - **hba1c_start**: the patient's HbA1c level at the beginning of the first week of treatment.
#
# - **hba1c_end**: the patient's HbA1c level at the end of the last week of treatment.
# - **hba1c_change**: the change in the patient's HbA1c level from the start of treatment to the end, i.e., `hba1c_start - hba1c_end`.

# %% [markdown]
# ### 2.1 Display data
#
# Display the first 10 rows of the `treatments` data, and visually inspect the data. Identify 3 instances of problematic data quality issues corresponding to **completeness** and **consistency** in the dataset.
#
# Hints:
# - For the first completeness issue, recall that the size of each treatment arm was 175 patients in each for the Auralin and Novodra arms. How many records should we have in the dataset, and how many rows does the treatments data currently contain?
# - For the second completeness issue, take a look at the `hba1c_change` variable. Is there anything noticable about the values for this column? What could we do to mitigate this during cleaning?
# - For the consistency issue, take a look at the `given_name` and `surname` variables. How are these different from what we saw in the `patients` dataframe?

# %%
#FILL IN - inspect the first 10 rows of the treatments data
treatments.head(10)
# Out:
#   given_name     surname    auralin    novodra  hba1c_start  hba1c_end  \
# 0   veronika    jindrová  41u - 48u          -         7.63       7.20
# 1     elliot  richardson          -  40u - 45u         7.56       7.09
# 2   yukitaka    takenaka          -  39u - 36u         7.68       7.25
# 3       skye  gormanston  33u - 36u          -         7.97       7.62
# 4     alissa      montez          -  33u - 29u         7.78       7.46
# 5    jasmine       sykes          -  42u - 44u         7.56       7.18
# 6     sophia      haugen  37u - 42u          -         7.65       7.27
# 7      eddie      archer  31u - 38u          -         7.89       7.55
# 8      saber      ménard          -  54u - 54u         8.08       7.70
# 9       asia     woźniak  30u - 36u          -         7.76       7.37
#
#    hba1c_change
# 0           NaN
# 1          0.97
# 2           NaN
# 3          0.35
# 4          0.32
# 5          0.38
# 6          0.38
# 7          0.34
# 8           NaN
# 9           NaN

# %%
#FILL IN - calculate the number of rows in your data
treatments.shape
# Out:
# (280, 7)

# %%
#Fill in - More code if needed
treatments.isna().
# Out:
#      given_name  surname  auralin  novodra  hba1c_start  hba1c_end  \
# 0         False    False    False    False        False      False
# 1         False    False    False    False        False      False
# 2         False    False    False    False        False      False
# 3         False    False    False    False        False      False
# 4         False    False    False    False        False      False
# ..          ...      ...      ...      ...          ...        ...
# 275       False    False    False    False        False      False
# 276       False    False    False    False        False      False
# 277       False    False    False    False        False      False
# 278       False    False    False    False        False      False
# 279       False    False    False    False        False      False
#
#      hba1c_change
# 0            True
# 1           False
# 2            True
# 3           False
# 4           False
# ..            ...
# 275         False
# 276          True
# 277         False
# 278         False
# 279         False
#
# [280 rows x 7 columns]

# %% [markdown]
# ### 2.2. Identifiy issues
#
# FILL IN the identified issues. For each issue, denote the row and column where the issue takes place:
#
# - Issue 1 (Completeness): Row ..., column ....  The issue is...
# - Issue 2 (Completeness): Row ..., column ....  ...
# - Issue 3 (Consistency): Row ..., column ....  ...

# %% [markdown]
# ### 2.3 Data structural issue
#
# Identify one data structural issue in the dataset - take a look at the `auralin` and `novodra` columns. Why are these variables causing a messy dataset (what rule of tidiness do they violate?), and how should they be structured instead?

# %% [markdown]
# *FILL IN*
#
# - Issue (Structural): ...
